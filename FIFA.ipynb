# %% [markdown]
# # 1. Importing relevant libraries and reading dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style ="ticks")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the dataset

# %%
df=pd.read_csv("fifa.csv")
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df2=pd.read_csv("fifa_ variable_information.csv")
df2
# Out:
#                           ID          unique id for every player
# 0                       Name                                name
# 1                        Age                                 age
# 2                      Photo           url to the player's photo
# 3                Nationality                         nationality
# 4                       Flag       url to players's country flag
# 5                    Overall                      overall rating
# 6                  Potential                    potential rating
# 7                       Club                        current club
# 8                  Club Logo                    url to club logo
# 9                      Value                current market value
# 10                      Wage                        current wage
# 11            Preferred Foot                          left/right
# 12  International Reputation                rating on scale of 5
# ...

# %% [markdown]
# # 2. Checking basic info of dataset

# %%
df.shape
# Out:
# (18207, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %% [markdown]
# # 3. Drop Redundant columns

# %%
## dropping 'Photo', 'Flag' and 'Club Logo'
df.drop(['Photo','Flag','Club Logo'],axis=1,inplace=True)

# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [markdown]
# # 4. Convert the columns "Value", "Wage", "Release Clause" to float datatype after getting rid of currency symbol and suffix.

# %%
df['Value'].dtype
# Out:
# dtype('O')

# %%
df['Wage'].dtype
# Out:
# dtype('O')

# %%
df['Release Clause'].dtype
# Out:
# dtype('O')

# %%
df['Value'] = df['Value'].replace({'\€': ''}, regex=True)
df['Wage'] = df['Wage'].replace({'\€': ''}, regex=True)
df['Release Clause'] = df['Release Clause'].replace({'\€': ''}, regex=True)

# %%
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club   Value  Wage Preferred Foot  ...  Composure  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Club                          241
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# HeadingAccuracy                48
# ShortPassing                   48
# Volleys                        48
# ...

# %%
def currency_convert(x):
    if pd.isnull(x) == True:
        return float(x)
    if 'M' in x:
        return float(x.replace('M', ''))*1000000
    elif 'K' in x:
        return float(x.replace('K', ''))*1000
    else:
        return float(x)
        
df['Value'] = df.apply(lambda x: currency_convert(x['Value']),axis=1)

# %%
df['Wage'] = df.apply(lambda x: currency_convert(x['Wage']),axis=1)

# %%
df['Release Clause'] = df.apply(lambda x: currency_convert(x['Release Clause']),axis=1)

# %%
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club        Value      Wage Preferred Foot  ...  \
# ...

# %% [markdown]
# # 5. Convert the column "Joined" into integer data type with keeping only the year

# %%
df['Joined'] = pd.DatetimeIndex(df['Joined']).year

# %%
df['Joined']
# Out:
# 0        2004.0
# 1        2018.0
# 2        2017.0
# 3        2011.0
# 4        2015.0
#           ...
# 18202    2017.0
# 18203    2018.0
# 18204    2017.0
# 18205    2018.0
# 18206    2018.0
# Name: Joined, Length: 18207, dtype: float64

# %%
df['Joined'] = df['Joined'].astype('Int64')

# %%
df['Joined'].dtype
# Out:
# Int64Dtype()

# %%
print('datatype of date:',df['Joined'].dtype)
# Out:
# datatype of date: Int64

# %%
df['Joined']
# Out:
# 0        2004
# 1        2018
# 2        2017
# 3        2011
# 4        2015
#          ...
# 18202    2017
# 18203    2018
# 18204    2017
# 18205    2018
# 18206    2018
# Name: Joined, Length: 18207, dtype: Int64

# %% [markdown]
# # 6. Convert the column "Contract Valid Until" to pandas datetime type

# %%
df['Contract Valid Until']
# Out:
# 0        2021
# 1        2022
# 2        2022
# 3        2020
# 4        2023
#          ...
# 18202    2019
# 18203    2020
# 18204    2021
# 18205    2019
# 18206    2019
# Name: Contract Valid Until, Length: 18207, dtype: object

# %%
df['Contract Valid Until']=pd.to_datetime(df['Contract Valid Until'])

# %%
display(df.iloc[28])
# Out:
# ID                                       198710
# Name                               J. Rodríguez
# Age                                          26
# Nationality                            Colombia
# Overall                                      88
# Potential                                    89
# Club                          FC Bayern München
# Value                                69500000.0
# Wage                                   315000.0
# Preferred Foot                             Left
# International Reputation                    4.0
# Weak Foot                                   3.0
# Skill Moves                                 4.0
# Work Rate                        Medium/ Medium
# Body Type                                Normal
# Position                                    LAM
# Jersey Number                              10.0
# Joined                                     <NA>
# Loaned From                         Real Madrid
# Contract Valid Until        2019-06-30 00:00:00
# ...

# %% [markdown]
# # 7. The column 'Height' is in inches with a quotation mark, Convert to float with decimal points

# %%
df['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
def parse_ht(x):
    # format: 7' 0.0"
    x=str(x)
    ht_ = x.split("'")
    ft_ = float(ht_[0])
    if len(ht_)>1:
        in_ = float(ht_[1])
    else:
        in_=0.0
    return ft_ + (in_/12.0)
    

df['Height']=df.apply(lambda x: parse_ht(x['Height']),axis=1)

# %%
df['Height']
# Out:
# 0        5.583333
# 1        6.166667
# 2        5.750000
# 3        6.333333
# 4        5.916667
#            ...
# 18202    5.750000
# 18203    6.250000
# 18204    5.666667
# 18205    5.833333
# 18206    5.833333
# Name: Height, Length: 18207, dtype: float64

# %% [markdown]
# # 8. The column "Weight" has the suffix as lbs, remove the suffix and convert to float

# %%
df['Weight']
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
df['Weight'] = df['Weight'].replace({'lbs': ''}, regex=True).astype(float)

# %%
df['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %% [markdown]
# # 9. Check for the percentage of missing values and impute them with appropriate imputation techniques

# %%
print(df.isnull().mean()*100)
# Out:
# ID                           0.000000
# Name                         0.000000
# Age                          0.000000
# Nationality                  0.000000
# Overall                      0.000000
# Potential                    0.000000
# Club                         1.323667
# Value                        0.000000
# Wage                         0.000000
# Preferred Foot               0.263635
# International Reputation     0.263635
# Weak Foot                    0.263635
# Skill Moves                  0.263635
# Work Rate                    0.263635
# Body Type                    0.263635
# Position                     0.329544
# Jersey Number                0.329544
# Joined                       8.529686
# Loaned From                 93.057615
# Contract Valid Until         1.587302
# Height                       0.263635
# Weight                       0.263635
# Crossing                     0.263635
# Finishing                    0.263635
# HeadingAccuracy              0.263635
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # 10. Plot the distribution of Overall rating for all the players and write your findings

# %%
sns.displot(df['Overall'], kde=True)
plt.show()

# %% [markdown]
# - From the above plot we can see that maximum players have a rating between 60 to 75

# %% [markdown]
# # 11. Retrieve the names of top20 players based on the Overall rating

# %%
d_top20 = df.nlargest(20, 'Overall')
print(d_top20[['Name','Overall']])
# Out:
#                  Name  Overall
# 0            L. Messi       94
# 1   Cristiano Ronaldo       94
# 2           Neymar Jr       92
# 3              De Gea       91
# 4        K. De Bruyne       91
# 5           E. Hazard       91
# 6           L. Modrić       91
# 7           L. Suárez       91
# 8        Sergio Ramos       91
# 9            J. Oblak       90
# 10     R. Lewandowski       90
# 11           T. Kroos       90
# 12           D. Godín       90
# 13        David Silva       90
# 14           N. Kanté       89
# 15          P. Dybala       89
# 16            H. Kane       89
# 17       A. Griezmann       89
# 18      M. ter Stegen       89
# 19        T. Courtois       89

# %% [markdown]
# # 12. Generate a dataframe which should include all the information of the top 20 players based on the Overall rating

# %%
d_top20
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 9   200389           J. Oblak   25    Slovenia       90         93
# 10  188545     R. Lewandowski   29      Poland       90         90
# 11  182521           T. Kroos   28     Germany       90         90
# 12  182493           D. Godín   32     Uruguay       90         90
# ...

# %% [markdown]
# # 13. What is the average "Age" and "Wage" of these top 20 players?

# %%
pd.DataFrame(d_top20[['Age','Wage']].mean(), columns=['Average'])
# Out:
#        Average
# Age       28.3
# Wage  289700.0

# %% [markdown]
# # 14. Among the top 20 players based on the Overall rating, which player has the highest wage? Display the name of the player with his wage

# %%
d_top20[['Wage']].max()
# Out:
# Wage    565000.0
# dtype: float64

# %%
d_highest_wage=d_top20.nlargest(1, 'Wage')
d_highest_wage[['Name','Wage']]
# Out:
#        Name      Wage
# 0  L. Messi  565000.0

# %% [markdown]
# # 15. Generate a dataframe which should include the "Player name", "Club Name", "Wage", and 'Overall rating'

# %%
df_4 = pd.DataFrame(df[['Name','Club','Wage','Overall']])
df_4
# Out:
#                      Name                 Club      Wage  Overall
# 0                L. Messi         FC Barcelona  565000.0       94
# 1       Cristiano Ronaldo             Juventus  405000.0       94
# 2               Neymar Jr  Paris Saint-Germain  290000.0       92
# 3                  De Gea    Manchester United  260000.0       91
# 4            K. De Bruyne      Manchester City  355000.0       91
# ...                   ...                  ...       ...      ...
# 18202        J. Lundstram      Crewe Alexandra    1000.0       47
# 18203  N. Christoffersson       Trelleborgs FF    1000.0       47
# 18204           B. Worman     Cambridge United    1000.0       47
# 18205      D. Walker-Rice      Tranmere Rovers    1000.0       47
# 18206           G. Nugent      Tranmere Rovers    1000.0       46
#
# [18207 rows x 4 columns]

# %%
df_4.rename(columns = {'Name':'Player name', 'Club':'Club Name', 'Overall':'Overall rating'}, inplace = True)
df_4
# Out:
#               Player name            Club Name      Wage  Overall rating
# 0                L. Messi         FC Barcelona  565000.0              94
# 1       Cristiano Ronaldo             Juventus  405000.0              94
# 2               Neymar Jr  Paris Saint-Germain  290000.0              92
# 3                  De Gea    Manchester United  260000.0              91
# 4            K. De Bruyne      Manchester City  355000.0              91
# ...                   ...                  ...       ...             ...
# 18202        J. Lundstram      Crewe Alexandra    1000.0              47
# 18203  N. Christoffersson       Trelleborgs FF    1000.0              47
# 18204           B. Worman     Cambridge United    1000.0              47
# 18205      D. Walker-Rice      Tranmere Rovers    1000.0              47
# 18206           G. Nugent      Tranmere Rovers    1000.0              46
#
# [18207 rows x 4 columns]

# %% [markdown]
# - i) find the average Overall rating for each club

# %%
temp_df=pd.DataFrame(df_4.groupby('Club Name')['Overall rating'].mean()).rename(columns={'Overall rating': 'Average Overall Rating'})
temp_df
# Out:
#                        Average Overall Rating
# Club Name
#  SSV Jahn Regensburg                65.586207
# 1. FC Heidenheim 1846               65.750000
# 1. FC Kaiserslautern                63.384615
# 1. FC Köln                          70.785714
# 1. FC Magdeburg                     65.615385
# ...                                       ...
# Zagłębie Sosnowiec                  60.760000
# Çaykur Rizespor                     66.900000
# Örebro SK                           60.481481
# Östersunds FK                       63.545455
# Śląsk Wrocław                       62.200000
#
# [651 rows x 1 columns]

# %% [markdown]
# - ii) Display the average overall rating of Top10 Clubs using a plot

# %%
df_4_top10=temp_df.nlargest(10, 'Average Overall Rating')
df_4_top10
# Out:
#                      Average Overall Rating
# Club Name
# Juventus                          82.280000
# Napoli                            80.000000
# Inter                             79.750000
# Real Madrid                       78.242424
# Milan                             78.074074
# FC Barcelona                      78.030303
# Paris Saint-Germain               77.433333
# Roma                              77.423077
# Manchester United                 77.242424
# FC Bayern München                 77.000000

# %%
df_4_top10.plot(kind='bar')
plt.show()

# %% [markdown]
# # 16. What is the relationship between age and individual potential of the player? Visualize the relationship with appropriate plot and Comment on the same

# %%
sns.lineplot(x= 'Age', y= 'Potential', data = df, color='blue')
plt.show()

# %% [markdown]
# - As the age of the players increases, the potential decreases

# %% [markdown]
# # 17. Which features directly contribute to the wages of the players?

# %%
sns.pairplot(df[['Potential','Overall','Value','International Reputation','Release Clause','Wage']])
plt.show()

# %% [markdown]
# - Wage increases with potential
# - Wage increases with Overall rating of a player
# - Wage increases with international reputation

# %% [markdown]
# # 18. Find the position in the pitch where the maximum number of players play and the position where the minimum number of players play? Display it using a plot

# %%
pd.DataFrame(df['Position'].value_counts().sort_values(ascending=False).head(1))
# Out:
#     Position
# ST      2152

# %%
pd.DataFrame(df['Position'].value_counts().sort_values(ascending=True).head(1))
# Out:
#     Position
# LF        15

# %%
plt.figure(figsize=(20,5))
sns.histplot(df['Position'])
plt.show()

# %% [markdown]
# # 19. How many players are from the club 'Juventus' and the wage is greater than 200K? Display all the information of such players

# %%
df[(df['Club']=='Juventus') & (df['Wage']>200000)]
# Out:
#         ID               Name  Age Nationality  Overall  Potential      Club  \
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94  Juventus
# 15  211110          P. Dybala   24   Argentina       89         94  Juventus
# 24  138956       G. Chiellini   33       Italy       89         89  Juventus
#
#          Value      Wage Preferred Foot  ...  Composure  Marking  \
# 1   77000000.0  405000.0          Right  ...       95.0     28.0
# 15  89000000.0  205000.0           Left  ...       84.0     23.0
# 24  27000000.0  215000.0           Left  ...       84.0     93.0
#
#     StandingTackle SlidingTackle GKDiving GKHandling  GKKicking  \
# 1             31.0          23.0      7.0       11.0       15.0
# 15            20.0          20.0      5.0        4.0        4.0
# 24            93.0          90.0      3.0        3.0        2.0
#
#     GKPositioning GKReflexes Release Clause
# 1            14.0       11.0    127100000.0
# ...

# %% [markdown]
# # 20. Generate a data frame containing top 5 players by Overall rating for each unique position

# %%
df_top5 = df.groupby(['Position']).apply(lambda x : x.sort_values('Overall',ascending=False).head(5))
df_top5
# Out:
#                  ID               Name  Age Nationality  Overall  Potential  \
# Position
# CAM      17  194765       A. Griezmann   27      France       89         90
#          31  190460         C. Eriksen   26     Denmark       88         91
#          61  201942    Roberto Firmino   26      Brazil       86         87
#          66  189596          T. Müller   28     Germany       86         86
#          74  176635            M. Özil   29     Germany       86         86
# ...             ...                ...  ...         ...      ...        ...
# ST       1    20801  Cristiano Ronaldo   33    Portugal       94         94
#          10  188545     R. Lewandowski   29      Poland       90         90
#          16  202126            H. Kane   24     England       89         91
#          23  153079          S. Agüero   30   Argentina       89         89
#          36  173731            G. Bale   28       Wales       88         88
#
# ...

# %% [markdown]
# # 21. What is the average wage one can expect to pay for the top 5 players in every position?

# %%
pd.DataFrame(df_top5['Wage'].groupby('Position').mean()).rename(columns={'Wage': 'Average Wage'})
# Out:
#           Average Wage
# Position
# CAM           174000.0
# CB            139600.0
# CDM           217000.0
# CF             47400.0
# CM            130600.0
# GK            192800.0
# LAM            81600.0
# LB            177200.0
# LCB           162000.0
# LCM           184400.0
# LDM           126600.0
# LF            121200.0
# LM            164600.0
# LS            130200.0
# LW            261000.0
# LWB            34200.0
# RAM            45400.0
# RB            155400.0
# RCB           231000.0
# RCM           240800.0
# RDM           105000.0
# RF            148000.0
# RM            131400.0
# RS            132200.0
# RW            202000.0
# RWB            44200.0
# ST            294000.0
